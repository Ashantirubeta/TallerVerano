# %% [markdown]
# # Taller CGeo

# %%
Pkg.installed()
# Out:
# Dict{String,VersionNumber} with 31 entries:
#   "PDMats"            => v"0.6.0"
#   "Distributions"     => v"0.13.0"
#   "Rmath"             => v"0.1.6"
#   "SortingAlgorithms" => v"0.1.1"
#   "FixedPointNumbers" => v"0.3.8"
#   "Conda"             => v"0.5.3"
#   "SHA"               => v"0.3.3"
#   "PyCall"            => v"1.12.0"
#   "LaTeXStrings"      => v"0.2.1"
#   "ZMQ"               => v"0.4.3"
#   "JSON"              => v"0.12.0"
#   "StatsBase"         => v"0.15.0"
#   "DataArrays"        => v"0.4.1"
#   "ColorTypes"        => v"0.5.1"
#   "Compat"            => v"0.25.2"
#   "DataStructures"    => v"0.5.3"
#   "IJulia"            => v"1.5.0"
#   "PyPlot"            => v"2.3.2"
#   "Calculus"          => v"0.2.2"
#   "Colors"            => v"0.7.3"
#   "GZip"              => v"0.3.0"
#   "MbedTLS"           => v"0.4.5"
#   "MacroTools"        => v"0.3.6"
#   "FileIO"            => v"0.3.1"
#   "QuadGK"            => v"0.1.2"
#   ⋮                   => ⋮

# %%
Pkg.add("PyPlot")
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
using PyPlot
# Out:
# INFO: Precompiling module PyPlot.
# INFO: Installing matplotlib via the Conda matplotlib package...
# Fetching package metadata .........
# Solving package specifications: .
#
# Package plan for installation in environment /home/taller/.julia/v0.5/Conda/deps/usr:
#
# The following NEW packages will be INSTALLED:
#
#     cairo:        1.14.8-0
#     cycler:       0.10.0-py27_0
#     matplotlib:   2.0.2-np112py27_0
#     pixman:       0.34.0-0
#     pycairo:      1.10.0-py27_0
#     pyparsing:    2.1.4-py27_0
#     pytz:         2017.2-py27_0
#     subprocess32: 3.2.7-py27_0
#
# The following packages will be UPDATED:
#
#     conda:        4.3.17-py27_0     --> 4.3.22-py27_0
#
# pixman-0.34.0- 100% |###############################| Time: 0:00:01   2.69 MB/sA:  0:00:00   2.10 MB/s
# pyparsing-2.1. 100% |###############################| Time: 0:00:00   3.31 MB/s
# pytz-2017.2-py 100% |###############################| Time: 0:00:00   4.91 MB/s6.15 MB/s
# ...

# %%
ra = rand(1000);

# %%
plot(ra)
xlabel("Index")
ylabel("Rand")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f537015a090>)
# PyObject <matplotlib.text.Text object at 0x7f534b1bdc90>
